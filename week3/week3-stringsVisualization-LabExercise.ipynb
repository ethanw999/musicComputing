# %% [markdown]
# <a href="https://colab.research.google.com/github/ethanw999/musicComputing/blob/main/week3/week3-stringsVisualization-LabExercise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Generate a time series

# %%
import numpy as np
radians = np.arange(0, 2*np.pi, 0.01);

# %% [markdown]
# # Plot the time series using the matplotlib library

# %%
import matplotlib.pylab as plt
# plot the time series against the same time series
# https://matplotlib.org/3.3.3/api/_as_gen/matplotlib.pyplot.plot.html
# plt.plot(xvals, yvals)
plt.plot(radians, radians)
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.axis('tight')
plt.show()

# %% [markdown]
# # Plot the time series against the sine of the time series

# %%
plt.plot(radians, np.sin(radians))
plt.xlabel('Radians')
plt.ylabel('Amplitude')
plt.show()

# %% [markdown]
# # Create strings for the x and y axis labels

# %%
xlabel = 'Radians'
ylabel = 'Amplitude'

# %% [markdown]
# # Plot using the label strings

# %%
plt.plot(radians, np.sin(radians))
plt.xlabel(xlabel)
plt.ylabel(ylabel)
plt.show()

# %% [markdown]
# # Plot the sine wave with degrees in the x-axis instead of radians

# %%
# use the numpy function rad2deg to convert
plt.plot(np.rad2deg(radians), np.sin(radians))
plt.xlabel('Degrees')
plt.ylabel(ylabel)
plt.show()

# %% [markdown]
# # Import an audio file from class GitHub repo using librosa library

# %%
# !git clone https://github.com/jcdevaney/imc2023.git

import librosa
import librosa.display
file = 'imc2023/audioFiles/avm.wav'
sig , sr = librosa.load(file,mono=True,sr=None)
# Out:
# Cloning into 'imc2023'...
# remote: Enumerating objects: 130, done.
# remote: Counting objects: 100% (34/34), done.
# remote: Compressing objects: 100% (16/16), done.
# remote: Total 130 (delta 28), reused 18 (delta 18), pack-reused 96 (from 1)
# Receiving objects: 100% (130/130), 16.27 MiB | 8.08 MiB/s, done.
# Resolving deltas: 100% (47/47), done.

# %% [markdown]
# # Calculate the length in seconds

# %%
length_s = sig.shape[0] / sr
print(length_s)
# Out:
# 12.466802721088435

# %% [markdown]
# # Plot the time-domain representation of avm.wav

# %%
plt.plot(sig)

# %% [markdown]
# # Plot with time on the x-axis

# %%
time=np.arange(0,sig.shape[0])/sr
plt.plot(time,sig)

# %% [markdown]
# # Plot with amplitude on the y-axis

# %%
excursion=max(abs(sig))
sigNew = sig / excursion
plt.plot(time,sigNew)

# %% [markdown]
# # Plot with labels

# %%
time=np.arange(0,sig.shape[0])/sr
plt.plot(time,sigNew)
plt.xlabel('Time (seconds)')
plt.ylabel(ylabel)
# Out:
# Text(0, 0.5, 'Amplitude')

# %% [markdown]
# Week Three Lab

# %%
# import libraries
import numpy as np
import matplotlib.pylab as plt
import librosa

# import files
# !git clone https://github.com/jcdevaney/imc2023.git
# Out:
# fatal: destination path 'imc2023' already exists and is not an empty directory.

# %%
# open the audio file avm2.wav with librosa.load()
file2 = 'imc2023/audioFiles/avm2.wav'
targetsr = 44100
sig2 , sr2 = librosa.load(file2,mono=True,sr=targetsr)
plt.plot(sig2)

# %%
#Adjust the x-axis to represent time
time2=np.arange(0,sig2.shape[0])/sr2
plt.plot(time2,sig2)

# %%
#Scale the y-axis to represent amplitude
excursion2=max(abs(sig2))
sigNew2 = sig2 / excursion2

#Plot a time-domain representation of the signal with matplotlib
plt.plot(time2,sigNew2)

#Label the x and y axes
# plt.xlabel('Time (Seconds)')
# plt.ylabel('Amplitude')

xlabel = 'Time (Seconds)'
ylabel = 'Amplitude'

plt.xlabel(xlabel)
plt.ylabel(ylabel)
# Out:
# Text(0, 0.5, 'Amplitude')
